# %% [markdown]
# ### Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
url="https://subslikescript.com/movie/Titanic-120338"
result=requests.get(url)
result.status_code
content=result.text
# print(content)
soup=BeautifulSoup(content,"html.parser")
# print(soup)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Titanic (1997) Movie Script
#  | Subs like Script
#   </title>
#   <meta "="" content="    Read " created="" from="" movie="" name="description" script,="" srt="" subtitles="" titanic"=""/>
#   <meta content="    transcript, movie, subtitles, scripts, film, video, media, subs, srt
# " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# subslikescript
# politifact.com

# %%
soup.find('h1')
# Out:
# <h1>Titanic (1997) - full transcript</h1>

# %%
soup.find('h1').text
# Out:
# 'Titanic (1997) - full transcript'

# %%
soup.find('h1').get_text()
# Out:
# 'Titanic (1997) - full transcript'

# %%
soup.find('h1').text.strip()
# Out:
# 'Titanic (1997) - full transcript'

# %%
soup.find('a')
# Out:
# <a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
# <span>SUBSLIKESCRIPT</span>
# </a>

# %%
soup.find('a',href=True)
# Out:
# <a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
# <span>SUBSLIKESCRIPT</span>
# </a>

# %%
soup.find_all('a',href=True)
# Out:
# [<a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
#  <span>SUBSLIKESCRIPT</span>
#  </a>,
#  <a href="/movies" target="_self" title="All movies transcripts">Movies</a>,
#  <a href="/series" target="_self" title="All Tv Shows transcripts">TV Shows</a>,
#  <a href="/">Home</a>,
#  <a href="/movies">Movies</a>,
#  <a href="/movies">All movie scripts</a>,
#  <a href="/series">All Tv-Show scripts</a>,
#  <a href="/dmca">DMCA</a>]

# %%
len(soup.find_all('a',href=True))
# Out:
# 8

# %%
soup.find('div')
# Out:
# <div class="page-wrapper">
# <header>
# <div id="logo">
# <a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
# <span>SUBSLIKESCRIPT</span>
# </a>
# </div>
# <nav>
# <a href="/movies" target="_self" title="All movies transcripts">Movies</a>
# <a href="/series" target="_self" title="All Tv Shows transcripts">TV Shows</a>
# </nav>
# </header>
# <div class="main-wrapper">
# <main class="mainpage">
# <nav>
# <ul class="breadcrumb">
# <li><a href="/">Home</a></li>
# <li><a href="/movies">Movies</a></li>
# <li>Titanic - subtitles like script</li>
# </ul>
# </nav>
# <nav>
# <form action="https://subslikescript.com/search" class="searchzone" method="get" name="search">
# <input class="searchbox" name="q" type="text" value=""/>
# <button class="searchbutton">Search</button>
# </form>
# </nav>
# <article class="main-article">
# <h1>Titanic (1997) - full transcript</h1>
# ...

# %%
soup.find('article',class_='main-article')
# Out:
# <article class="main-article">
# <h1>Titanic (1997) - full transcript</h1>
# <p class="plot">A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.</p>
# <div class="full-script" data-imdb-id="120338" id="cue-app">
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="0" data-line-idx="0">13 meters. You should see it.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="1" data-line-idx="0">Okay, take her up and over the bow rail.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="2" data-line-idx="0">Mir 2, we're going over the bow.</p>
# <p class="cue-line" data-cue-idx="2" data-line-idx="1">Stay with us.</p>
# </div>
# <div class="subtitle-cue">
# <p class="cue-line" data-cue-idx="3" data-line-idx="0">Okay, quiet. We're rolling.</p>
# </div>
# <div class="subtitle-cue">
# ...

# %%
print(soup.find('article',class_='main-article').text)
# Out:
# Titanic (1997) - full transcript
# A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.
#
#
# 13 meters. You should see it.
#
#
# Okay, take her up and over the bow rail.
#
#
# Mir 2, we're going over the bow.
# Stay with us.
#
#
# Okay, quiet. We're rolling.
#
#
# Seeing her coming out of the
# darkness like a ghost ship...
#
#
# still gets me every time.
#
#
# To see the sad ruin of the
# great ship sitting here...
#
#
# where she landed at
# 2:30 in the morning
#
#
# of April 15, 1912...
#
#
# after her long fall...
#
#
# from the world above.
#
#
# You are so full of shit, boss.
#
#
# Dive 6. Here we are again
# on the deck of Titanic.
#
#
# 21/2 miles down. 3,821 meters.
#
#
# The pressure outside is
# 31/2 tons per square inch.
#
#
# These windows are
# 9 inches thick.
#
#
# If they go, it's sayonara
# in two microseconds.
#
#
# All right, enough of that bullshit.
#
#
# Just put her down on the roof of
# ...

# %%
movie=soup.find('article',class_='main-article')
movie.find('h1').text
# Out:
# 'Titanic (1997) - full transcript'

# %%
print(movie.find('div',class_='full-script').text.strip())
# Out:
# 13 meters. You should see it.
#
#
# Okay, take her up and over the bow rail.
#
#
# Mir 2, we're going over the bow.
# Stay with us.
#
#
# Okay, quiet. We're rolling.
#
#
# Seeing her coming out of the
# darkness like a ghost ship...
#
#
# still gets me every time.
#
#
# To see the sad ruin of the
# great ship sitting here...
#
#
# where she landed at
# 2:30 in the morning
#
#
# of April 15, 1912...
#
#
# after her long fall...
#
#
# from the world above.
#
#
# You are so full of shit, boss.
#
#
# Dive 6. Here we are again
# on the deck of Titanic.
#
#
# 21/2 miles down. 3,821 meters.
#
#
# The pressure outside is
# 31/2 tons per square inch.
#
#
# These windows are
# 9 inches thick.
#
#
# If they go, it's sayonara
# in two microseconds.
#
#
# All right, enough of that bullshit.
#
#
# Just put her down on the roof of
# the officers' quarters like yesterday.
#
#
# Mir 2, we're landing right over the
# Grand Staircase. You guys set to launch?
#
#
# Yeah, Brock. Launching Dunkin now.
# ...

# %%
print(movie.find('div',class_='full-script').get_text(strip=True))
# Out:
# 13 meters. You should see it.Okay, take her up and over the bow rail.Mir 2, we're going over the bow.Stay with us.Okay, quiet. We're rolling.Seeing her coming out of thedarkness like a ghost ship...still gets me every time.To see the sad ruin of thegreat ship sitting here...where she landed at2:30 in the morningof April 15, 1912...after her long fall...from the world above.You are so full of shit, boss.Dive 6. Here we are againon the deck of Titanic.21/2 miles down. 3,821 meters.The pressure outside is31/2 tons per square inch.These windows are9 inches thick.If they go, it's sayonarain two microseconds.All right, enough of that bullshit.Just put her down on the roof ofthe officers' quarters like yesterday.Mir 2, we're landing right over theGrand Staircase. You guys set to launch?Yeah, Brock. Launching Dunkin now.Go, Charlie.- All right, tether out.- Tether out.Okay, Brock, we're droppingdown along the hull.Yeah, roger that. Okay, drop down and gointo the first class gangway door.I wa
# ...

# %%
script=movie.find('div',class_='full-script').get_text()

# %%
print(script)
# Out:
# 13 meters. You should see it.
#
#
# Okay, take her up and over the bow rail.
#
#
# Mir 2, we're going over the bow.
# Stay with us.
#
#
# Okay, quiet. We're rolling.
#
#
# Seeing her coming out of the
# darkness like a ghost ship...
#
#
# still gets me every time.
#
#
# To see the sad ruin of the
# great ship sitting here...
#
#
# where she landed at
# 2:30 in the morning
#
#
# of April 15, 1912...
#
#
# after her long fall...
#
#
# from the world above.
#
#
# You are so full of shit, boss.
#
#
# Dive 6. Here we are again
# on the deck of Titanic.
#
#
# 21/2 miles down. 3,821 meters.
#
#
# The pressure outside is
# 31/2 tons per square inch.
#
#
# These windows are
# 9 inches thick.
#
#
# If they go, it's sayonara
# in two microseconds.
#
#
# All right, enough of that bullshit.
#
#
# Just put her down on the roof of
# the officers' quarters like yesterday.
#
#
# Mir 2, we're landing right over the
# Grand Staircase. You guys set to launch?
#
#
# Yeah, Brock. Launching Dunkin now.
# ...

# %%
script.encode()
# Out:
# b'\n\n13 meters. You should see it.\n\n\nOkay, take her up and over the bow rail.\n\n\nMir 2, we\'re going over the bow.\nStay with us.\n\n\nOkay, quiet. We\'re rolling.\n\n\nSeeing her coming out of the\ndarkness like a ghost ship...\n\n\nstill gets me every time.\n\n\nTo see the sad ruin of the\ngreat ship sitting here...\n\n\nwhere she landed at\n2:30 in the morning\n\n\nof April 15, 1912...\n\n\nafter her long fall...\n\n\nfrom the world above.\n\n\nYou are so full of shit, boss.\n\n\nDive 6. Here we are again\non the deck of Titanic.\n\n\n21/2 miles down. 3,821 meters.\n\n\nThe pressure outside is\n31/2 tons per square inch.\n\n\nThese windows are\n9 inches thick.\n\n\nIf they go, it\'s sayonara\nin two microseconds.\n\n\nAll right, enough of that bullshit.\n\n\nJust put her down on the roof of\nthe officers\' quarters like yesterday.\n\n\nMir 2, we\'re landing right over the\nGrand Staircase. You guys set to launch?\n\n\nYeah, Brock. Launching Dunkin now.\nGo, Charlie.\n\n\n- A
# ...

# %%
soup.find('h1').text.strip().split()[0]
# Out:
# 'Titanic'

# %%
with open('titanic.txt','w',encoding='utf-8') as file:
    file.write(script)

# %%
# with open(f'{title}.txt','w',encoding='utf-8') as file:
    # file.write(script)

# %%
import requests
from bs4 import BeautifulSoup
url="https://subslikescript.com/movies"
result=requests.get(url)
content=result.text
# print(content)
soup=BeautifulSoup(content,"html.parser")
# print(soup)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    All English transcripts for movies  | Subs like Script
#   </title>
#   <meta content="List of movie scripts " name="description"/>
#   <meta content="transcript, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="BuKJjheqZZzt4Wn0HvPS37UG1DitppibXOtMm3yM" name="csrf-token"/>
# ...

# %%
len(soup.find_all('a',href=True))
# Out:
# 86

# %%
box=soup.find('article',class_='main-article')

# %%
len(box.find_all('a',href=True))
# Out:
# 30

# %%
links=[]
for i in box.find_all('a'):
    links.append("https://subslikescript.com"+i['href'])
    # print(i.text)

# %%
links
# Out:
# ['https://subslikescript.com/movie/Diamantes_negros-2362320',
#  'https://subslikescript.com/movie/The_Filmmaker-6645798',
#  'https://subslikescript.com/movie/Love_in_the_Sand_Dunes-206720',
#  'https://subslikescript.com/movie/Tombstone-Rashomon-5669410',
#  'https://subslikescript.com/movie/Escape_to_Witch_Mountain-72951',
#  'https://subslikescript.com/movie/Mystery_Island_Winner_Takes_All-35660815',
#  'https://subslikescript.com/movie/Vampire_Circus-67924',
#  'https://subslikescript.com/movie/The_Unstoppable_Man-186657',
#  'https://subslikescript.com/movie/Temptations-41626',
#  'https://subslikescript.com/movie/The_Forest_Clown-32474968',
#  'https://subslikescript.com/movie/House_of_the_Seasons-29579063',
#  'https://subslikescript.com/movie/Two_Gophers_from_Texas-40909',
#  'https://subslikescript.com/movie/The_Golden_West-26923682',
#  'https://subslikescript.com/movie/Evelyne-12771214',
#  'https://subslikescript.com/movie/Trip_to_Papa-23032852',
# ...

# %%
for i in links:
    result=requests.get(i)
    content=result.text
    soup=BeautifulSoup(content,'html.parser')
    box=soup.find('article',class_='main-article')
    title=box.find('h1').text
    script=box.find('div',class_='full-script').text
    try:
        with open(f"{title}.txt","w",encoding='utf-8') as file:
            file.write(script)
    except Exception as e:
        print(e)

# %%
for i in links:
    result=requests.get(i)
    content=result.text
    soup=BeautifulSoup(content,'html.parser')
    box=soup.find('article',class_='main-article')
    title=box.find('h1').text.split(":")[0]
    script=box.find('div',class_='full-script').text
    try:
        with open(f"{title}.txt","w",encoding='utf-8') as file:
            file.write(script)
    except Exception as e:
        print(e)

# %%
result=requests.get('https://subslikescript.com/movie/MMA_Meu_Melhor_Amigo-31917839')
content=result.text
soup=BeautifulSoup(content,'html.parser')
box=soup.find('article',class_='main-article')
script=box.find('div',class_='full-script').text
try:
    with open("Hello.txt","w",encoding='utf-8') as file:
        file.write(script)
except Exception as e:
    print(e)

# %%
import requests
from bs4 import BeautifulSoup
url="https://www.politifact.com/factchecks/"
result=requests.get(url)
content=result.text
# print(content)
soup=BeautifulSoup(content,"html.parser")
# print(soup)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description">
#    <meta content="all" name="robots">
#     <meta content="PolitiFact" name="publisher"/>
#     <meta content="PolitiFact" name="twitter:username">
#      <meta content="summary" name="twitter:card">
#       <meta content="PolitiFact" name="twitter:site"/>
#       <meta content="" name="twitter:url">
#        <meta content="" name="twitter:title"/>
#        <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %%
len(soup.find_all('a',href=True))
# Out:
# 165

# %%
# 20/05/2026

# %%
movie=soup.find_all('li',class_="o-listicle__item")
movie
# Out:
# [<li class="o-listicle__item">
#  <article class="m-statement m-statement--is-medium m-statement--fire">
#  <div class="m-statement__author">
#  <div class="m-statement__avatar">
#  <div class="m-statement__image">
#  <div class="c-image" style="padding-top: 119.27710843373494%;">
#  <img class="c-image__thumb" height="99" src="https://static.politifact.com/CACHE/images/politifact/mugs/logo-black/4590875651af69b2c789ceab409664dd.jpg" width="83"/>
#  <picture>
#  <img class="c-image__original" height="178" src="https://static.politifact.com/CACHE/images/politifact/mugs/logo-black/72988380e8c8bd188dc360d11552e4a0.jpg" width="166"/>
#  </picture>
#  </div>
#  </div>
#  </div>
#  <div class="m-statement__meta">
#  <a class="m-statement__name" href="/personalities/tweets/" title="X posts">
#                       X posts
#                    </a>
#  <div class="m-statement__desc">
#                      stated on May 14, 2026 in X posts:
#                    </div>
#  </div>
#  </div>
# ...

# %%
data=soup.find_all('div',class_="m-statement__meta")
data
# Out:
# [<div class="m-statement__meta">
#  <a class="m-statement__name" href="/personalities/tweets/" title="X posts">
#                       X posts
#                    </a>
#  <div class="m-statement__desc">
#                      stated on May 14, 2026 in X posts:
#                    </div>
#  </div>,
#  <div class="m-statement__meta">
#  <a class="m-statement__name" href="/personalities/tweets/" title="X posts">
#                       X posts
#                    </a>
#  <div class="m-statement__desc">
#                      stated on May 6, 2026 in an X post:
#                    </div>
#  </div>,
#  <div class="m-statement__meta">
#  <a class="m-statement__name" href="/personalities/kathy-castor/" title="Kathy Castor">
#                      Kathy Castor
#                    </a>
#  <div class="m-statement__desc">
#                      stated on April 29, 2026 in an X post:
#                    </div>
#  </div>,
#  <div class="m-statement__meta">
# ...

# %%
tag=[]
data1=soup.find_all('a',class_="m-statement__name")
for i in data1:
    tag.append(i.get_text().strip())
tag
# Out:
# ['X posts',
#  'X posts',
#  'Kathy Castor',
#  'Vivek Ramaswamy',
#  'TikTok posts',
#  'Christine Quinn',
#  'Nicholas Langworthy',
#  'Donald Trump',
#  'Byron Donalds',
#  'Marcy Kaptur',
#  'Liz Krueger',
#  'X posts',
#  'Donald Trump',
#  'Sam Sutton',
#  'Fentrice Driskell',
#  'Instagram posts',
#  'Bernie Sanders',
#  'Tim Scott',
#  'Pine Tree Results PAC',
#  'Social Media',
#  'Donald Trump',
#  'Ron DeSantis',
#  'Social Media',
#  'Jay Collins',
#  'Robert F. Kennedy Jr.',
#  'Joe Rogan',
#  'X posts',
#  'Chris Wright',
#  'Facebook posts',
#  'Democratic National Committee']

# %%
data2=soup.find_all('div',class_="m-statement__quote")
data2
# Out:
# [<div class="m-statement__quote">
#  <a href="/factchecks/2026/may/15/tweets/byron-donalds-florida-insider-trading/">
#
#                          Video shows U.S. Rep. Byron Donalds saying, “Insider trading should absolutely be allowed for members of Congress.”
#
#                        </a>
#  </div>,
#  <div class="m-statement__quote">
#  <a href="/factchecks/2026/may/14/tweets/hantavirus-quarantine-crisis-actor-rosmarin/">
#
#                          An American passenger on the cruise ship involved in the hantavirus outbreak is a "crisis actor."
#
#                        </a>
#  </div>,
#  <div class="m-statement__quote">
#  <a href="/factchecks/2026/may/14/kathy-castor/kid-care-florida-desantis-health-insurance/">
#
#                          “Florida is the only state in the nation kicking children off their affordable health coverage.”
#
#                        </a>
#  </div>,
#  <div class="m-statement__quote">
# ...

# %%
st=[]
for i in data2:
    s=data2.find('a',href=True).text
    st.append(s)
st
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 st=[]
#       2 for i in data2:
# ----> 3     s=data2.find('a',href=True).text
#       4     st.append(s)
#       5 st
#
# File C:\ProgramData\anaconda3\Lib\site-packages\bs4\element.py:2902, in ResultSet.__getattr__(self, key)
#    2900 def __getattr__(self, key: str) -> None:
#    2901     """Raise a helpful exception to explain a common code fix."""
# -> 2902     raise AttributeError(
#    2903         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2904     )
#
# AttributeError: ResultSet object has no attribute "find". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('politifact.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Fact-checks | PolitiFact
#   </title>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="description"/>
#   <meta content="all" name="robots"/>
#   <meta content="PolitiFact" name="publisher"/>
#   <meta content="PolitiFact" name="twitter:username"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="PolitiFact" name="twitter:site"/>
#   <meta content="" name="twitter:url"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="PolitiFact is a fact-checking website that rates the accuracy of claims by elected officials and others on its Truth-O-Meter." name="twitter:description"/>
# ...

# %%
from bs4 import BeautifulSoup
import requests
upperframe=[]
for page in range(1,5):
    url="https://www.politifact.com/factchecks/?page="+str(page)
    pages=requests.get(url)
    soup=BeautifulSoup(pages.text,'html.parser')
    frame=[]
    links=soup.find_all('li',class_='o-listicle__item')
    for j in links:
        statement=j.find('div',class_='m-statement__quote').text.strip()
        link="https://politifact.com"
        link+=j.find('div',class_="m-statement__quote").find("a")['href'].strip()
        date=j.find("div",class_='m-statement__body').find('footer').text.split("• ")[-1]
        source=j.find("a",class_="m-statement__name").text.strip()
        frame.append((statement,link,date,source))
    upperframe.extend(frame)    
print(upperframe)
# Out:
# [('Video shows U.S. Rep. Byron Donalds saying, “Insider trading should absolutely be allowed for members of Congress.”', 'https://politifact.com/factchecks/2026/may/15/tweets/byron-donalds-florida-insider-trading/', 'May 15, 2026\n                  ', 'X posts'), ('An American passenger on the cruise ship involved in the hantavirus outbreak is a "crisis actor."', 'https://politifact.com/factchecks/2026/may/14/tweets/hantavirus-quarantine-crisis-actor-rosmarin/', 'May 14, 2026\n                  ', 'X posts'), ('“Florida is the only state in the nation kicking children off their affordable health coverage.”', 'https://politifact.com/factchecks/2026/may/14/kathy-castor/kid-care-florida-desantis-health-insurance/', 'May 14, 2026\n                  ', 'Kathy Castor'), ('In 2020, “Amy Acton called off Ohio’s election at the last minute.”', 'https://politifact.com/factchecks/2026/may/13/vivek-ramaswamy/Amy-Acton-Ohio-2020-covid-primary-senate/', 'May 13, 2026\n                  ', 'Vivek R
# ...

# %%
import pandas as pd
df=pd.DataFrame(upperframe)
df
# Out:
#                                                      0  \
# 0    Video shows U.S. Rep. Byron Donalds saying, “I...
# 1    An American passenger on the cruise ship invol...
# 2    “Florida is the only state in the nation kicki...
# 3    In 2020, “Amy Acton called off Ohio’s election...
# 4    Imágenes muestran a personas “infectadas con H...
# ..                                                 ...
# 115  A letter sent to postal service employees abou...
# 116  “By federal law, if you sign someone up for Me...
# 117  "If we stop this fraud, this massive fraud, we...
# 118  A document shows Minnesota shooting victim Ren...
# 119  Credit card companies would be “in violation o...
#
#                                                      1  \
# 0    https://politifact.com/factchecks/2026/may/15/...
# 1    https://politifact.com/factchecks/2026/may/14/...
# 2    https://politifact.com/factchecks/2026/may/14/...
# 3    https://politifact.com/factchecks/2026/may/13/...
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('top250.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# ...

# %%
movie=soup.find_all("td",class_="titleColumn")
movie
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=1a264172-ae11-42e4-8ef7-7fed1973bb8f&amp;pf_rd_r=3AQ5G29EBVVKV41WYCWB&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_1" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=1a264172-ae11-42e4-8ef7-7fed1973bb8f&amp;pf_rd_r=3AQ5G29EBVVKV41WYCWB&amp;pf_rd_s=center-1&amp;pf_rd_t=15506&amp;pf_rd_i=top&amp;ref_=chttp_tt_2" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
# ...

# %%
title=[]
for i in movie:
    title.append(i.find('a').text.strip())
print(title)
# Out:
# ['The Shawshank Redemption', 'The Godfather', 'The Dark Knight', 'The Godfather Part II', '12 Angry Men', "Schindler's List", 'The Lord of the Rings: The Return of the King', 'Pulp Fiction', 'The Lord of the Rings: The Fellowship of the Ring', 'The Good, the Bad and the Ugly', 'Spider-Man: Across the Spider-Verse', 'Forrest Gump', 'Fight Club', 'The Lord of the Rings: The Two Towers', 'Inception', 'Star Wars: Episode V - The Empire Strikes Back', 'The Matrix', 'Goodfellas', "One Flew Over the Cuckoo's Nest", 'Se7en', "It's a Wonderful Life", 'Seven Samurai', 'The Silence of the Lambs', 'Saving Private Ryan', 'City of God', 'Interstellar', 'Life Is Beautiful', 'The Green Mile', 'Star Wars: Episode IV - A New Hope', 'Terminator 2: Judgment Day', 'Back to the Future', 'Spirited Away', 'The Pianist', 'Psycho', 'Parasite', 'Léon: The Professional', 'The Lion King', 'Gladiator', 'American History X', 'The Departed', 'Whiplash', 'The Prestige', 'The Usual Suspects', 'Casablanca', 'Grave of 
# ...

# %%
len(soup.find_all('td',class_='titleColumn'))
# Out:
# 250

# %%
rating=[]
for i in soup.find_all('td',class_='ratingColumn imdbRating'):
    y=i.text.strip()
    rating.append(y)
print(rating)
# Out:
# ['9.2', '9.2', '9.0', '9.0', '9.0', '8.9', '8.9', '8.8', '8.8', '8.8', '8.8', '8.8', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.4', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.3', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.2', '8.
# ...

# %%
year=[]
for i in soup.find_all('span',class_='secondaryInfo'):
    y=i.text[1:-1].strip()
    year.append(y)
print(year)
# Out:
# ['1994', '1972', '2008', '1974', '1957', '1993', '2003', '1994', '2001', '1966', '2023', '1994', '1999', '2002', '2010', '1980', '1999', '1990', '1975', '1995', '1946', '1954', '1991', '1998', '2002', '2014', '1997', '1999', '1977', '1991', '1985', '2001', '2002', '1960', '2019', '1994', '1994', '2000', '1998', '2006', '2014', '2006', '1995', '1942', '1988', '1962', '2011', '1936', '1968', '1988', '1954', '1979', '1931', '1979', '2000', '2012', '1981', '2008', '2006', '1950', '1957', '2018', '1980', '1940', '1957', '2018', '1986', '1999', '2012', '1964', '2009', '2003', '2017', '1984', '1995', '1995', '1981', '2019', '2019', '1997', '1997', '1984', '2016', '2009', '1952', '1963', '2000', '2018', '2010', '1983', '1985', '2004', '1968', '2012', '1992', '1962', '1941', '1931', '1952', '1959', '1960', '1958', '2001', '1944', '1971', '1987', '2020', '1983', '2010', '1995', '2009', '1962', '1973', '2011', '1927', '1997', '1988', '1989', '2000', '1976', '1948', '2007', '2019', '2016', '2004
# ...

# %%
# Mobile Name
# Color
# RAM
# ROM
# Rating
# Price

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('flipkart.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" style="">
#  <!--
#  Page saved with SingleFile
#  url: https://www.flipkart.com/search?q=realme%20phones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
#  saved date: Wed Jun 04 2025 01:14:51 GMT+0530 (India Standard Time)
# -->
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    :root{--sf-img-17: url("data:image/png;base64,...");--sf-img-19: url("data:image/webp;base64,...");--sf-img-20: url("data:image/webp;base64,...");--sf-img-23: url("data:image/webp;base64,...");--sf-img-29: url("data:image/webp;base64,...")}
#   </style>
#   <style id="react-native-stylesheet">
# ...

# %%
name=[]
for i in soup.find_all("div",class_="KzDlHZ"):
    y=i.text.strip().split('(')[0]
    name.append(y)
print(name)
# Out:
# ['realme C61 ', 'realme C61 ', 'realme C63 5G Charger in the Box ', 'realme P3x 5G ', 'realme C61 ', 'realme P2 Pro 5G ', 'realme Narzo N61 ', 'realme Narzo N61 ', 'realme C61 ', 'realme P3x 5G ', 'realme 14x 5G ', 'realme P3 5G ', 'realme P2 Pro 5G ', 'realme P2 Pro 5G ', 'realme P3 5G ', 'realme 14 Pro 5G ', 'realme Narzo N65 5G ', 'realme 13 Pro 5G ', 'realme 14 Pro+ 5G ', 'realme 14x 5G ', 'realme P3 5G ', 'realme 13 Pro+ 5G ', 'realme Narzo N65 5G ', 'realme 14 Pro 5G ']

# %%
color=[]
for i in soup.find_all("div",class_="KzDlHZ"):
    y=i.text.strip().split('(')[1].split(',')[0]
    color.append(y)
print(color)
# Out:
# ['Marble Black', 'Safari Green', 'Forest Green', 'Lunar Silver', 'Marble Black', 'Parrot Green', 'Marble Black', 'Vyage Blue', 'Safari Green', 'Midnight Blue', 'Jewel Red', 'Nebula Pink', 'Parrot Green', 'Parrot Green', 'Space Silver', 'Suede Grey', 'Ambr Gold', 'Monet Gold', 'Suede Grey', 'Crystal Black', 'Space Silver', 'Monet Purple', 'Deep Green', 'Jaipur Pink']

# %%
ROM=[]
for i in soup.find_all("div",class_="KzDlHZ"):
    y=i.text.strip().split('(')[1].split(',')[1].split(')')[0]
    ROM.append(y)
print(ROM)
# Out:
# [' 128 GB', ' 128 GB', ' 128 GB', ' 128 GB', ' 64 GB', ' 512 GB', ' 64 GB', ' 64 GB', ' 64 GB', ' 128 GB', ' 128 GB', ' 128 GB', ' 128 GB', ' 256 GB', ' 256 GB', ' 128 GB', ' 128 GB', ' 512 GB', ' 512 GB', ' 128 GB', ' 128 GB', ' 256 GB', ' 128 GB', ' 128 GB']

# %%
ram_data=soup.find_all('li',class_='J+igdf')
ram=[]
for i in ram_data:
    if "RAM" in i.text:
        ram.append(i.text.split('|')[0][:-1])
ram
# Out:
# ['6 GB RAM',
#  '6 GB RAM',
#  '6 GB RAM',
#  '6 GB RAM',
#  '4 GB RAM',
#  '12 GB RAM',
#  '4 GB RAM',
#  '4 GB RAM',
#  '4 GB RAM',
#  '6 GB RAM',
#  '6 GB RAM',
#  '6 GB RAM',
#  '8 GB RAM',
#  '12 GB RAM',
#  '8 GB RAM',
#  '8 GB RAM',
#  '6 GB RAM',
#  '12 GB RAM',
#  '12 GB RAM',
#  '6 GB RAM',
#  '6 GB RAM',
#  '8 GB RAM',
#  '4 GB RAM',
#  '8 GB RAM']

# %%
# 22/5/2026

# %%
rat=[]
rating=soup.find_all("div",class_="XQDdHH")
for i in rating[0:24]:
    rat.append(i.text.strip())
print(rat)
# Out:
# ['4.4', '4.4', '4.5', '4.5', '4.3', '4.4', '4.3', '4.3', '4.3', '4.5', '4.4', '4.4', '4.4', '4.4', '4.4', '4.4', '4.3', '4.3', '4.4', '4.4', '4.4', '4.4', '4.3', '4.4']

# %%
price=[]
p=soup.find_all("div",class_="Nx9bqj _4b5DiR")
for i in p:
    price.append(i.text)
print(price)
# Out:
# ['₹8,199', '₹8,199', '₹10,999', '₹13,999', '₹7,699', '₹20,999', '₹7,380', '₹7,335', '₹7,699', '₹13,999', '₹14,999', '₹15,999', '₹17,999', '₹19,999', '₹18,499', '₹24,999', '₹12,448', '₹26,999', '₹37,999', '₹14,999', '₹15,999', '₹25,999', '₹10,471', '₹24,999']

# %%
frame=[]
for i in range(0,23):
    frame.append((name[i],color[i],ROM[i],ram[i],price[i],rat[i]))
import pandas as pd
df=pd.DataFrame(frame,columns=['Name','Color','ROM','RAM','Price','Rating'])
df
# Out:
#                                  Name          Color      ROM        RAM  \
# 0                         realme C61    Marble Black   128 GB   6 GB RAM
# 1                         realme C61    Safari Green   128 GB   6 GB RAM
# 2   realme C63 5G Charger in the Box    Forest Green   128 GB   6 GB RAM
# 3                      realme P3x 5G    Lunar Silver   128 GB   6 GB RAM
# 4                         realme C61    Marble Black    64 GB   4 GB RAM
# 5                   realme P2 Pro 5G    Parrot Green   512 GB  12 GB RAM
# 6                   realme Narzo N61    Marble Black    64 GB   4 GB RAM
# 7                   realme Narzo N61      Vyage Blue    64 GB   4 GB RAM
# 8                         realme C61    Safari Green    64 GB   4 GB RAM
# 9                      realme P3x 5G   Midnight Blue   128 GB   6 GB RAM
# 10                     realme 14x 5G       Jewel Red   128 GB   6 GB RAM
# 11                      realme P3 5G     Nebula Pink   128 GB   6 GB RAM
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(open('Popular_Quotes.html','r',encoding='utf-8'))
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="desktop withSiteHeaderTopFullImage">
#  <head>
#   <title>
#    Popular Quotes
#   </title>
#   <meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I'm selfish, impatient and a little ..." name="description"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://www.goodreads.com/quotes" rel="canonical"/>
#   <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->
#   <script>
#    //<![CDATA[
#     !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();
#
#     if (window.csa) {
#       window.csa("Config", {
#         "Application": "GoodreadsMonolith",
# ...

# %%
quote=[]
q=soup.find_all('div',class_="quoteText")
for i in q:
    quote.append(i.text.strip().split("\n")[0])
quote
# Out:
# ['“Be yourself; everyone else is already taken.”',
#  "“I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”",
#  '“So many books, so little time.”',
#  "“Two things are infinite: the universe and human stupidity; and I'm not sure about the universe.”",
#  '“A room without books is like a body without a soul.”',
#  "“Be who you are and say what you feel, because those who mind don't matter, and those who matter don't mind.”",
#  "“You've gotta dance like there's nobody watching,Love like you'll never be hurt,Sing like there's nobody listening,And live like it's heaven on earth.”",
#  "“You know you're in love when you can't fall asleep because reality is finally better than your dreams.”",
#  '“You only live once, but if you do it right, once is enough.”',
#  '“Be the change that you wish to see in the world.”',
# ...

# %%
author=[]
q=soup.find_all('div',class_="quoteText")
for i in q:
    y=i.text.strip().split("\n")[4]
    author.append(y.strip())
author
# Out:
# ['Oscar Wilde',
#  'Marilyn Monroe',
#  'Frank Zappa',
#  'Albert Einstein',
#  'Marcus Tullius Cicero',
#  'Bernard M. Baruch',
#  'William W. Purkey',
#  'Dr. Seuss',
#  'Mae West',
#  'Mahatma Gandhi',
#  'Robert Frost',
#  'J.K. Rowling,',
#  'Albert Camus',
#  'Mark Twain',
#  'C.S. Lewis,',
#  'Maya Angelou',
#  'Elbert Hubbard',
#  'Oscar Wilde',
#  'Oscar Wilde',
#  'Martin Luther King Jr.,',
#  'Mahatma Gandhi',
#  'Stephen Chbosky,',
#  'Friedrich Nietzsche,',
#  'Oscar Wilde,',
#  'Ralph Waldo Emerson',
#  'Steve Jobs',
#  'Narcotics Anonymous',
#  'Marilyn Monroe',
#  'Andre Gide,',
#  'H. Jackson Brown Jr.,']

# %%
likes=[]
l=soup.find_all('a',class_="smallText")
for i in l:
    y=i.text.split(" ")[0]
    likes.append(y)
likes
# Out:
# ['172090',
#  '162993',
#  '147069',
#  '146082',
#  '133363',
#  '128599',
#  '127116',
#  '124987',
#  '117240',
#  '113213',
#  '108002',
#  '100983',
#  '92274',
#  '90869',
#  '87553',
#  '87398',
#  '83514',
#  '83168',
#  '80923',
#  '77451',
#  '77061',
#  '74875',
#  '73251',
#  '71126',
#  '69009',
#  '67728',
#  '64173',
#  '61795',
#  '61028',
#  '59792']

# %%
frame=[]
for i in range(0,30):
    frame.append((quote[i],author[i],likes[i]))
import pandas as pd
df=pd.DataFrame(frame,columns=["Quote","Author","Likes"])
df
# Out:
#                                                 Quote  \
# 0      “Be yourself; everyone else is already taken.”
# 1   “I'm selfish, impatient and a little insecure....
# 2                    “So many books, so little time.”
# 3   “Two things are infinite: the universe and hum...
# 4   “A room without books is like a body without a...
# 5   “Be who you are and say what you feel, because...
# 6   “You've gotta dance like there's nobody watchi...
# 7   “You know you're in love when you can't fall a...
# 8   “You only live once, but if you do it right, o...
# 9   “Be the change that you wish to see in the wor...
# 10  “In three words I can sum up everything I've l...
# 11  “If you want to know what a man's like, take a...
# 12  “Don’t walk in front of me… I may not followDo...
# 13  “If you tell the truth, you don't have to reme...
# 14  “Friendship ... is born at the moment when one...
# 15  “I've learned that people will forget what you...
# ...

# %%
# API KEY
# 14cc9e943ea5aaaf895820eb43e32924

# %%
# API_Key-14cc9e943ea5aaaf895820eb43e32924

# %%
import requests,json
def get_coordinates():
    api_key=input("Enter API Key: ")
    city=input("Enter City Name: ")
    # request_url=f'http://api.openweathermap.org/geo/1.0/direct?q={city}&appid={api_key}'
    request_url='http://api.openweathermap.org/geo/1.0/direct?q='+city+'&appid='+api_key
    response=requests.get(request_url)
    coordinates=response.json()
    # print(coordinates)
    # print(json.dumps(coordinates,indent=5))
    lattitude=coordinates[0]['lat']
    longitude=coordinates[0]['lon']
    return lattitude,longitude,city
lat,lon,city=get_coordinates()
print(city)
print("--------------")
print("Lattitude:",lat)
print("longitude:",lon)
# Out:
# Enter API Key:  14cc9e943ea5aaaf895820eb43e32924
# Enter City Name:  Ahmedabad
# Ahmedabad
# --------------
# Lattitude: 23.0215374
# longitude: 72.5800568

# %%
import requests,json
def current_weather_data():
    api_key=input("Enter API Key: ")
    request_url="https://api.openweathermap.org/data/2.5/weather?lat="+str(lat)+"&lon="+str(lon)+"&appid="+api_key
    response=requests.get(request_url)
    current_weather=response.json()
    print(json.dumps(current_weather,indent=5))
    description=current_weather['weather'][0]['description']
    temperature=current_weather['main'][0]['temp']
    print(description)
description=current_weather_data()
print("description")
# Out:
# Enter API Key:  14cc9e943ea5aaaf895820eb43e32924
# {
#      "coord": {
#           "lon": 72.5801,
#           "lat": 23.0215
#      },
#      "weather": [
#           {
#                "id": 711,
#                "main": "Smoke",
#                "description": "smoke",
#                "icon": "50d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 307.19,
#           "feels_like": 307.05,
#           "temp_min": 307.19,
#           "temp_max": 307.19,
#           "pressure": 1009,
#           "humidity": 33,
#           "sea_level": 1009,
#           "grnd_level": 1004
#      },
#      "visibility": 3000,
#      "wind": {
#           "speed": 2.06,
#           "deg": 280
#      },
#      "clouds": {
#           "all": 0
#      },
#      "dt": 1779426262,
#      "sys": {
#           "type": 1,
#           "id": 9049,
#           "country": "IN",
#           "sunrise": 1779409580,
#           "sunset": 1779457596
#      },
# ...
